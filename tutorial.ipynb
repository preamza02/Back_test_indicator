# %%
import numpy as np
import pandas as pd 
from BackTest import Back_Test,Fast_Back_Test

# %% [markdown]
# # load your data

# %%
price_path = 'raw_data\coin_Bitcoin.csv'
full_data = pd.read_csv(price_path)
full_data['Date'] = pd.to_datetime(full_data['Date'])
full_data
# Out:
#        SNo     Name Symbol                Date          High           Low  \
# 0        1  Bitcoin    BTC 2013-04-29 23:59:59    147.488007    134.000000
# 1        2  Bitcoin    BTC 2013-04-30 23:59:59    146.929993    134.050003
# 2        3  Bitcoin    BTC 2013-05-01 23:59:59    139.889999    107.720001
# 3        4  Bitcoin    BTC 2013-05-02 23:59:59    125.599998     92.281898
# 4        5  Bitcoin    BTC 2013-05-03 23:59:59    108.127998     79.099998
# ...    ...      ...    ...                 ...           ...           ...
# 2986  2987  Bitcoin    BTC 2021-07-02 23:59:59  33939.588699  32770.680780
# 2987  2988  Bitcoin    BTC 2021-07-03 23:59:59  34909.259899  33402.696536
# 2988  2989  Bitcoin    BTC 2021-07-04 23:59:59  35937.567147  34396.477458
# 2989  2990  Bitcoin    BTC 2021-07-05 23:59:59  35284.344430  33213.661034
# 2990  2991  Bitcoin    BTC 2021-07-06 23:59:59  35038.536363  33599.916169
#
#               Open         Close        Volume     Marketcap
# ...

# %% [markdown]
# ## change your data format to pandas.dataframe (columns = ['date','price'])

# %%
price_data = full_data[['Date','Close']] #['date','price']
price_data.columns = ['date','price']
price_data
# Out:
#                     date         price
# 0    2013-04-29 23:59:59    144.539993
# 1    2013-04-30 23:59:59    139.000000
# 2    2013-05-01 23:59:59    116.989998
# 3    2013-05-02 23:59:59    105.209999
# 4    2013-05-03 23:59:59     97.750000
# ...                  ...           ...
# 2986 2021-07-02 23:59:59  33897.048590
# 2987 2021-07-03 23:59:59  34668.548402
# 2988 2021-07-04 23:59:59  35287.779766
# 2989 2021-07-05 23:59:59  33746.002456
# 2990 2021-07-06 23:59:59  34235.193451
#
# [2991 rows x 2 columns]

# %% [markdown]
# # use Back_test

# %%
EMA_agent_1 = Back_Test.EMA_Back_Test(price_data,12,26)
EMA_agent_1.process()
# Out:
# BUY position date : 2013-05-24 23:59:59 size : 75.07507679512727 price : 133.1999969482422
# Sell positionnumber 1 from : 2013-05-24 23:59:59 size: 75.07507679512727 price : 111.5 profit -21.699996948242188
# BUY position date : 2013-07-26 23:59:59 size : 87.17822742289876 price : 96.02020263671876
# Sell positionnumber 1 from : 2013-07-26 23:59:59 size: 87.17822742289876 price : 126.0 profit 29.979797363281236
# BUY position date : 2013-10-09 23:59:59 size : 84.04970885366714 price : 130.69000244140625
# Sell positionnumber 1 from : 2013-10-09 23:59:59 size: 84.04970885366714 price : 522.7000122070312 profit 392.010009765625
# BUY position date : 2014-01-03 23:59:59 size : 53.66033004676717 price : 818.719970703125
# Sell positionnumber 1 from : 2014-01-03 23:59:59 size: 53.66033004676717 price : 811.9099731445312 profit -6.80999755859375
# BUY position date : 2014-05-21 23:59:59 size : 88.59295626107469 price : 491.7699890136719
# ...

# %%
EMA_agent_2 = Back_Test.EMA_Back_Test(price_data,12,26,show_log = False) #not show log
EMA_agent_2.process()
# Out:
# Result
# form 2013-04-29 23:59:59 to 2021-07-06 23:59:59
# init money : 10000
# money : 8256382.060560616
# asset : 0
# total_asset_value : 8256382.060560616
# total_profit = 82463.82060560616 %
# win_rate = 57.142857142857146 %  total_trade = 35
# first price = 144.5399932861328 last price = 34235.19345116 change = 23685.619926235686 %

# %%
EMA_agent_3 = Back_Test.EMA_Back_Test(price_data,12,26,show_log = False) #not show log 
EMA_agent_3.process(show_grab = False) #not show grab
# Out:
# Result
# form 2013-04-29 23:59:59 to 2021-07-06 23:59:59
# init money : 10000
# money : 8256382.060560616
# asset : 0
# total_asset_value : 8256382.060560616
# total_profit = 82463.82060560616 %
# win_rate = 57.142857142857146 %  total_trade = 35
# first price = 144.5399932861328 last price = 34235.19345116 change = 23685.619926235686 %

# %%
EMA_fast = Fast_Back_Test.EMA_Fast_Back_Test(price_data,12,26)
EMA_fast.process()
# Out:
# total_assert_value : 8256382.060560616
# total_profit = 82463.82060560616 %
